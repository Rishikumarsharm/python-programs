# %%
###data manuplation and analysis
##large dataset   #csv->comma seperated value
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("used_bikes.csv") ##used to read any file
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
#dataframe --2d tabular data structure
#series --1d

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
#create a dataframe
dict1={
    "name":["anil","lokesh","punit","vikash"],
    "roll":[1,2,3,4],
    "marks":[98,99,78,88]
}

# %%
newdf=pd.DataFrame(dict1)
newdf
# Out:
#      name  roll  marks
# 0    anil     1     98
# 1  lokesh     2     99
# 2   punit     3     78
# 3  vikash     4     88

# %%
arr=np.arange(60).reshape(12,5)
dd=pd.DataFrame(arr)
dd
# Out:
#      0   1   2   3   4
# 0    0   1   2   3   4
# 1    5   6   7   8   9
# 2   10  11  12  13  14
# 3   15  16  17  18  19
# 4   20  21  22  23  24
# 5   25  26  27  28  29
# 6   30  31  32  33  34
# 7   35  36  37  38  39
# 8   40  41  42  43  44
# 9   45  46  47  48  49
# 10  50  51  52  53  54
# 11  55  56  57  58  59

# %%
dd1=pd.DataFrame(arr,columns=["a","b","c","d","e"])
dd1
# Out:
#      a   b   c   d   e
# 0    0   1   2   3   4
# 1    5   6   7   8   9
# 2   10  11  12  13  14
# 3   15  16  17  18  19
# 4   20  21  22  23  24
# 5   25  26  27  28  29
# 6   30  31  32  33  34
# 7   35  36  37  38  39
# 8   40  41  42  43  44
# 9   45  46  47  48  49
# 10  50  51  52  53  54
# 11  55  56  57  58  59

# %%
df.head() #it shows first 5
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.tail() #it shows last 5
# Out:
#                        bike_name    price    city  kms_driven        owner  \
# 32643     Hero Passion Pro 100cc  39000.0   Delhi     22000.0  First Owner
# 32644       TVS Apache RTR 180cc  30000.0  Karnal      6639.0  First Owner
# 32645   Bajaj Avenger Street 220  60000.0   Delhi     20373.0  First Owner
# 32646  Hero Super Splendor 125cc  15600.0  Jaipur     84186.0  First Owner
# 32647         Bajaj Pulsar 150cc  22000.0    Pune     60857.0  First Owner
#
#         age  power  brand
# 32643   4.0  100.0   Hero
# 32644   9.0  180.0    TVS
# 32645   6.0  220.0  Bajaj
# 32646  16.0  125.0   Hero
# 32647  13.0  150.0  Bajaj

# %%
newdf["roll"]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: roll, dtype: int64

# %%
type(newdf["roll"])
# Out:
# pandas.core.series.Series

# %%
df["age"]
# Out:
# 0         3.0
# 1         4.0
# 2         8.0
# 3         4.0
# 4         3.0
#          ...
# 32643     4.0
# 32644     9.0
# 32645     6.0
# 32646    16.0
# 32647    13.0
# Name: age, Length: 32648, dtype: float64

# %%
df["age"].dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# bike_name      object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
##multiple fetch
df[["age","price"]]
# Out:
#         age     price
# 0       3.0   35000.0
# 1       4.0  119900.0
# 2       8.0  600000.0
# 3       4.0   65000.0
# 4       3.0   80000.0
# ...     ...       ...
# 32643   4.0   39000.0
# 32644   9.0   30000.0
# 32645   6.0   60000.0
# 32646  16.0   15600.0
# 32647  13.0   22000.0
#
# [32648 rows x 2 columns]

# %%
df[["age","price","city"]]
# Out:
#         age     price       city
# 0       3.0   35000.0  Ahmedabad
# 1       4.0  119900.0      Delhi
# 2       8.0  600000.0      Delhi
# 3       4.0   65000.0  Bangalore
# 4       3.0   80000.0  Bangalore
# ...     ...       ...        ...
# 32643   4.0   39000.0      Delhi
# 32644   9.0   30000.0     Karnal
# 32645   6.0   60000.0      Delhi
# 32646  16.0   15600.0     Jaipur
# 32647  13.0   22000.0       Pune
#
# [32648 rows x 3 columns]

# %%
df.T
# Out:
#                                          0                            1      \
# bike_name   TVS Star City Plus Dual Tone 110cc  Royal Enfield Classic 350cc
# price                                  35000.0                     119900.0
# city                                 Ahmedabad                        Delhi
# kms_driven                             17654.0                      11000.0
# owner                              First Owner                  First Owner
# age                                        3.0                          4.0
# power                                    110.0                        350.0
# brand                                      TVS                Royal Enfield
#
#                            2                     3      \
# bike_name   Triumph Daytona 675R  TVS Apache RTR 180cc
# price                   600000.0               65000.0
# city                       Delhi             Bangalore
# kms_driven                 110.0               16329.0
# ...

# %%
#indexing
df[0:10]
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
##indexing --loc->location based indexing
#,iloc-->integer based

# %%
##iloc ---[row start:end:skip,"columns start:end:skip]
df.iloc[0:10,0:5]
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner
# 0   First Owner
# 1   First Owner
# 2   First Owner
# 3   First Owner
# 4   First Owner
# 5   First Owner
# ...

# %%
##iloc ---[row start:end:skip,"columns start:end:skip]
df.iloc[0:10:2,0:5]
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 6         Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 8     Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
#
#          owner
# 0  First Owner
# 2  First Owner
# 4  First Owner
# 6  First Owner
# 8  First Owner

# %%
df.loc[0:10,["age","price"]]
# Out:
#     age     price
# 0   3.0   35000.0
# 1   4.0  119900.0
# 2   8.0  600000.0
# 3   4.0   65000.0
# 4   3.0   80000.0
# 5   6.0   53499.0
# 6   3.0   85000.0
# 7   3.0   45000.0
# 8   3.0  145000.0
# 9   7.0   88000.0
# 10  7.0   72000.0

# %%
df.loc[0:10,["bike_name"	,"price"	]]
# Out:
#                                    bike_name     price
# 0         TVS Star City Plus Dual Tone 110cc   35000.0
# 1                Royal Enfield Classic 350cc  119900.0
# 2                       Triumph Daytona 675R  600000.0
# 3                       TVS Apache RTR 180cc   65000.0
# 4       Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0
# 5                           Yamaha FZs 150cc   53499.0
# 6              Honda CB Hornet 160R  ABS DLX   85000.0
# 7        Hero Splendor Plus Self Alloy 100cc   45000.0
# 8          Royal Enfield Thunderbird X 350cc  145000.0
# 9   Royal Enfield Classic Desert Storm 500cc   88000.0
# 10                  Yamaha YZF-R15 2.0 150cc   72000.0

# %%
#predefine fnction
df[["price"]]
# Out:
#           price
# 0       35000.0
# 1      119900.0
# 2      600000.0
# 3       65000.0
# 4       80000.0
# ...         ...
# 32643   39000.0
# 32644   30000.0
# 32645   60000.0
# 32646   15600.0
# 32647   22000.0
#
# [32648 rows x 1 columns]

# %%
df[["price"]].max()
# Out:
# price    1900000.0
# dtype: float64

# %%
df[["price"]].min()
# Out:
# price    4400.0
# dtype: float64

# %%
df[["price"]].mean()
# Out:
# price    68295.417637
# dtype: float64

# %%
df[["price"]].sum()
# Out:
# price    2.229709e+09
# dtype: float64

# %%
df[["price"]].std()
# Out:
# price    90718.595205
# dtype: float64

# %%
df.max()
# Out:
# bike_name     Yezdi Classic 250cc
# price                   1900000.0
# city                     Zirakpur
# kms_driven               750000.0
# owner                 Third Owner
# age                          63.0
# power                      1800.0
# brand                       Yezdi
# dtype: object

# %%
df.min()
# Out:
# bike_name     BMW F750 GS 850cc
# price                    4400.0
# city                 24 Pargana
# kms_driven                  1.0
# owner               First Owner
# age                         1.0
# power                     100.0
# brand                       BMW
# dtype: object

# %%
df["city"].unique() # it return unique values
# Out:
# array(['Ahmedabad', 'Delhi', 'Bangalore', 'Mumbai', 'Kalyan', 'Faridabad',
#        'Mettur', 'Hyderabad', 'Kaithal', 'Gurgaon', 'Pune', 'Noida',
#        'Nashik', 'Kochi', 'Allahabad', 'Samastipur', 'Nadiad', 'Lucknow',
#        'Jaipur', 'Karnal', 'Gorakhpur', 'Vidisha', 'Hosur', 'Bagalkot',
#        'Baripara', 'Agra', 'Dharwad', 'Vadodara', 'Jalandhar', 'Surat',
#        'Chennai', 'Navi Mumbai', 'Gandhidham', 'Visakhapatnam',
#        'Thrissur', 'Kolkata', 'Ernakulam', 'Barasat', 'Ghaziabad',
#        'Bhubaneshwar', 'Amritsar', 'Bhopal', 'Hamirpur(hp)', 'Kottayam',
#        'Arrah', 'Patiala', 'Ranga Reddy', 'Mandi', 'Ludhiana', 'Mandya',
#        'Siliguri', 'Aurangabad', 'Kanpur', 'Bhilwara', 'Meerut', 'Rewari',
#        'Ahmednagar', 'Wardha', 'Chandigarh', 'Ranchi', 'Panvel', 'Thane',
#        'Jabalpur', 'Kota', 'Rohtak', 'Rajkot', 'Varanasi', '24 Pargana',
#        'Banka', 'Nagpur', 'Banki', 'Pali', 'Chhatarpur', 'Katihar',
# ...

# %%
df["city"].nunique() # it return number of unique values
# Out:
# 443

# %%
df["city"].value_counts() # it return unique values repeating time
# Out:
# city
# Delhi            7318
# Bangalore        2723
# Mumbai           2591
# Hyderabad        2160
# Pune             1724
#                  ...
# Surendranagar       1
# Khandela            1
# Mohammadabad        1
# Shimla              1
# Sidhi               1
# Name: count, Length: 443, dtype: int64

# %%
df.head(10)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
df.columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='object')

# %%
df["owner"].value_counts()
# Out:
# owner
# First Owner             29964
# Second Owner             2564
# Third Owner               108
# Fourth Owner Or More       12
# Name: count, dtype: int64

# %%
df[df["owner"] == "Fourth Owner Or More"] #data filteration
# Out:
#                                          bike_name     price       city  \
# 2146                   Royal Enfield‎ Bullet 350cc   85990.0     Raipur
# 2999               Royal Enfield Thunderbird 350cc   95000.0      Delhi
# 3637                            Bajaj Pulsar 150cc   11000.0  Bangalore
# 4120                           Bajaj Avenger 220cc   37000.0  Ahmedabad
# 5221                        Yamaha Gladiator 125cc   20000.0  Bangalore
# 5456                        Yamaha Gladiator 125cc   20000.0  Bangalore
# 5568  Royal Enfield Classic 350cc-Redditch Edition  141000.0       Pune
# 6138                    Royal Enfield Bullet 350cc   89000.0    Lucknow
# 6755                    Royal Enfield Bullet 350cc   89000.0    Lucknow
# 6985                   Royal Enfield Classic 350cc   90000.0  Ghaziabad
# 7038            Royal Enfield Bullet Electra 350cc   35000.0      Delhi
# 9028                       Hero Passion Plus 100cc   23000.0   Anantnag
#
# ...

# %%
df[df["owner"] == "First Owner"] #data filteration
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
##city --delhi
df[df["city"]== "Delhi"]
# Out:
#                                  bike_name     price   city  kms_driven  \
# 1              Royal Enfield Classic 350cc  119900.0  Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0  Delhi       110.0
# 5                         Yamaha FZs 150cc   53499.0  Delhi     25000.0
# 6            Honda CB Hornet 160R  ABS DLX   85000.0  Delhi      8200.0
# 7      Hero Splendor Plus Self Alloy 100cc   45000.0  Delhi     12645.0
# ...                                    ...       ...    ...         ...
# 32639          Royal Enfield Classic 350cc   95500.0  Delhi     18000.0
# 32640               Hero Passion Pro 100cc   32000.0  Delhi     12000.0
# 32641                  Bajaj Avenger 220cc   41000.0  Delhi     20245.0
# 32643               Hero Passion Pro 100cc   39000.0  Delhi     22000.0
# 32645             Bajaj Avenger Street 220   60000.0  Delhi     20373.0
#
#               owner   age  power          brand
# 1       First Owner   4.0  350.0  Royal Enfield
# ...

# %%
##city --delhi
delhi=df[df["city"]== "Delhi"]
delhi
# Out:
#                                  bike_name     price   city  kms_driven  \
# 1              Royal Enfield Classic 350cc  119900.0  Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0  Delhi       110.0
# 5                         Yamaha FZs 150cc   53499.0  Delhi     25000.0
# 6            Honda CB Hornet 160R  ABS DLX   85000.0  Delhi      8200.0
# 7      Hero Splendor Plus Self Alloy 100cc   45000.0  Delhi     12645.0
# ...                                    ...       ...    ...         ...
# 32639          Royal Enfield Classic 350cc   95500.0  Delhi     18000.0
# 32640               Hero Passion Pro 100cc   32000.0  Delhi     12000.0
# 32641                  Bajaj Avenger 220cc   41000.0  Delhi     20245.0
# 32643               Hero Passion Pro 100cc   39000.0  Delhi     22000.0
# 32645             Bajaj Avenger Street 220   60000.0  Delhi     20373.0
#
#               owner   age  power          brand
# 1       First Owner   4.0  350.0  Royal Enfield
# ...

# %%
##delhi --price 60000
p=delhi[delhi["price"] <=60000.0] # data filteration on condition
p
# Out:
#                                  bike_name    price   city  kms_driven  \
# 5                         Yamaha FZs 150cc  53499.0  Delhi     25000.0
# 7      Hero Splendor Plus Self Alloy 100cc  45000.0  Delhi     12645.0
# 13                     Bajaj Discover 100M  29499.0  Delhi     20000.0
# 14                     Bajaj Discover 125M  29900.0  Delhi     20000.0
# 19                     Bajaj Discover 125M  29900.0  Delhi     20000.0
# ...                                    ...      ...    ...         ...
# 32637                   Bajaj Pulsar 150cc  25000.0  Delhi     32588.0
# 32640               Hero Passion Pro 100cc  32000.0  Delhi     12000.0
# 32641                  Bajaj Avenger 220cc  41000.0  Delhi     20245.0
# 32643               Hero Passion Pro 100cc  39000.0  Delhi     22000.0
# 32645             Bajaj Avenger Street 220  60000.0  Delhi     20373.0
#
#               owner   age  power   brand
# 5       First Owner   6.0  150.0  Yamaha
# ...

# %%
##multiple condition
##brand="tvs",age<=3,power<=110
df[(df["brand"]=="TVS") & (df["age"]<=3) & (df["power"]<=110.0)]
# Out:
#                                bike_name    price         city  kms_driven  \
# 0     TVS Star City Plus Dual Tone 110cc  35000.0    Ahmedabad     17654.0
# 986                      TVS Sport 100cc  34000.0        Delhi      8048.0
# 1084                     TVS Sport 100cc  34000.0        Delhi      8048.0
# 2360           TVS Victor 110cc Disc SBT  54000.0        Delhi      6000.0
# 2381           TVS Victor 110cc Disc SBT  54000.0        Delhi      6000.0
# 2494                     TVS Sport 100cc  39900.0    Bangalore     15000.0
# 2710                    TVS Victor 110cc  40000.0      Chennai     12530.0
# 3362                     TVS Sport 100cc  32000.0    Faridabad     15820.0
# 4114           TVS Radeon 110cc Drum SBT  38000.0        Delhi     21249.0
# 4251            TVS Star City Plus 110cc  51000.0    Ahmedabad     12000.0
# 5468                     TVS Sport 100cc  38000.0        Noida      8718.0
# ...

# %%
##multiple condition
##brand="tvs",age<=3,power<=110
df[(df["brand"]=="TVS") | (df["age"]<=3) | (df["power"]<=110.0)]
# Out:
#                                   bike_name    price         city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc  35000.0    Ahmedabad     17654.0
# 3                      TVS Apache RTR 180cc  65000.0    Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition  80000.0    Bangalore     10000.0
# 6             Honda CB Hornet 160R  ABS DLX  85000.0        Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc  45000.0        Delhi     12645.0
# ...                                     ...      ...          ...         ...
# 32629                   Bajaj Platina 100cc  23000.0      Lucknow     20000.0
# 32640                Hero Passion Pro 100cc  32000.0        Delhi     12000.0
# 32642                    Hero Passion 100cc  15000.0  Perumbavoor     35000.0
# 32643                Hero Passion Pro 100cc  39000.0        Delhi     22000.0
# 32644                  TVS Apache RTR 180cc  30000.0       Karnal      6639.0
#
# ...

# %%
##data cleaning
df.isnull()
# Out:
#        bike_name  price   city  kms_driven  owner    age  power  brand
# 0          False  False  False       False  False  False  False  False
# 1          False  False  False       False  False  False  False  False
# 2          False  False  False       False  False  False  False  False
# 3          False  False  False       False  False  False  False  False
# 4          False  False  False       False  False  False  False  False
# ...          ...    ...    ...         ...    ...    ...    ...    ...
# 32643      False  False  False       False  False  False  False  False
# 32644      False  False  False       False  False  False  False  False
# 32645      False  False  False       False  False  False  False  False
# 32646      False  False  False       False  False  False  False  False
# 32647      False  False  False       False  False  False  False  False
#
# [32648 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
## null values
df.dropna() ## it will delete the null value
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32643     True
# 32644     True
# 32645     True
# 32646     True
# 32647     True
# Length: 32648, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 25324

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.to_csv("new_numpy.csv",index=False)

# %%
#short values 10/04/2025
df.sort_values(by="price",ascending=False)
# Out:
#                         bike_name      price       city  kms_driven  \
# 367   Indian Chief Classic 1800cc  1900000.0    Chennai      1700.0
# 4864            BMW S 1000 RR Pro  1800000.0      Delhi      2600.0
# 7671         Yamaha YZF-R1 1000cc  1550000.0      Delhi      9800.0
# 6872           MV Agusta F3 800cc  1500000.0      Hubli      2000.0
# 3016            BMW S 1000 XR Pro  1500000.0      Delhi     18000.0
# ...                           ...        ...        ...         ...
# 4923           Bajaj Pulsar 150cc     6700.0      Delhi     81000.0
# 4922           Bajaj Pulsar 150cc     6400.0      Delhi    100000.0
# 1382              TVS Flame 125cc     5800.0  Ghaziabad     25000.0
# 9194          Hero Ambition 135cc     5000.0      Delhi     82178.0
# 4960         LML Freedom DX 110cc     4400.0    Godhara     55000.0
#
#              owner   age   power   brand
# 367    First Owner   6.0  1800.0  Indian
# 4864   First Owner   4.0  1000.0     BMW
# ...

# %%
#short values
df.sort_values(by=["price","age"],ascending=[False,False])
# Out:
#                         bike_name      price       city  kms_driven  \
# 367   Indian Chief Classic 1800cc  1900000.0    Chennai      1700.0
# 4864            BMW S 1000 RR Pro  1800000.0      Delhi      2600.0
# 7671         Yamaha YZF-R1 1000cc  1550000.0      Delhi      9800.0
# 1321      Ducati XDiavel 1262CC S  1500000.0     Alibag      7000.0
# 3016            BMW S 1000 XR Pro  1500000.0      Delhi     18000.0
# ...                           ...        ...        ...         ...
# 4923           Bajaj Pulsar 150cc     6700.0      Delhi     81000.0
# 4922           Bajaj Pulsar 150cc     6400.0      Delhi    100000.0
# 1382              TVS Flame 125cc     5800.0  Ghaziabad     25000.0
# 9194          Hero Ambition 135cc     5000.0      Delhi     82178.0
# 4960         LML Freedom DX 110cc     4400.0    Godhara     55000.0
#
#              owner   age   power   brand
# 367    First Owner   6.0  1800.0  Indian
# 4864   First Owner   4.0  1000.0     BMW
# ...

# %%
df.sort_index()
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
##nan values
dt={
    "name":["lokesh","anil","mohan","ram"],
    "class":[1,2,3,4],
    "age":[10,15,20,np.nan]
}
df1=pd.DataFrame(dt)
df1
# Out:
#      name  class   age
# 0  lokesh      1  10.0
# 1    anil      2  15.0
# 2   mohan      3  20.0
# 3     ram      4   NaN

# %%
df1.isnull()
# Out:
#     name  class    age
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False   True

# %%
df1.isnull().sum()
# Out:
# name     0
# class    0
# age      1
# dtype: int64

# %%
df1.isnull().sum().sum()
# Out:
# 1

# %%
#delete null value
df1.dropna()
# Out:
#      name  class   age
# 0  lokesh      1  10.0
# 1    anil      2  15.0
# 2   mohan      3  20.0

# %%
df1.dropna(axis=1) #0 for row and 1 for columns
# Out:
#      name  class
# 0  lokesh      1
# 1    anil      2
# 2   mohan      3
# 3     ram      4

# %%
#fill null values --constant,mean,median
df1.fillna(0)
# Out:
#      name  class   age
# 0  lokesh      1  10.0
# 1    anil      2  15.0
# 2   mohan      3  20.0
# 3     ram      4   0.0

# %%
df1.fillna(df1.mean())
df1.fillna(df1.meadian())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 df1.fillna(df1.mean())
#       2 df1.fillna(df1.meadian())
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# ...

# %%
#df.loc[0:10,["price"]]=np.nan
df

# %%
df.fillna(df["price"].mean())
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.fillna(df["price"].median())
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
##add value in a particular columns
df["price"]
# Out:
# 0        35000.0
# 1       119900.0
# 2       600000.0
# 3        65000.0
# 4        80000.0
#           ...
# 9362     25000.0
# 9369     35000.0
# 9370    450000.0
# 9371    139000.0
# 9372     80000.0
# Name: price, Length: 7324, dtype: float64

# %%
## creating new columns
df["increased_price"]=df["price"]+5000

# %%
## creating new columns
df["increased_price"]=df["price"]+5000

# %%
#checking the table
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
# ...

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand  increased_price
# 0  First Owner  3.0  110.0            TVS          40000.0
# 1  First Owner  4.0  350.0  Royal Enfield         124900.0
# 2  First Owner  8.0  675.0        Triumph         605000.0
# 3  First Owner  4.0  180.0            TVS          70000.0
# 4  First Owner  3.0  150.0         Yamaha          85000.0

# %%
##drop column
df.drop("increased_price",axis=1)
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
#rename the column name
df.rename(columns={"price":"new_price"})
# Out:
#                                  bike_name  new_price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc    35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc   119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R   600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc    65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition    80000.0  Bangalore     10000.0
# ...                                    ...        ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc    25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc    35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS   450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS   139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220    80000.0  Hyderabad      7127.0
#
# ...

# %%
#creating a group
owner_group=df.groupby("owner")

# %%
owner_group.get_group("First Owner")
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
# ...

# %%
df["owner"].value_counts()
# Out:
# owner
# First Owner             6642
# Second Owner             588
# Third Owner               84
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
#df.["price"].max()
#aggregate function
owner_group["age"].agg(max_age="max",min_age="min",mean_age="mean")
# Out:
#                       max_age  min_age   mean_age
# owner
# First Owner              43.0      1.0   6.446101
# Fourth Owner Or More     37.0      4.0  14.400000
# Second Owner             63.0      2.0   8.290816
# Third Owner              43.0      4.0  10.928571
