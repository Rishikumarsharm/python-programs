# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#df = sns.load_dataset("tips")
#df.head()

# %%
import pandas as pd
df=pd.read_csv("tips.csv")
df.to_csv("tips.csv",index=False)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.plot(df["total_bill"])

# %%
sns.lineplot(df["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.scatterplot(df["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.scatterplot(x=df["total_bill"],y=df["tip"],data=df)
plt.title("graph",fontsize=20,
          color="red"
          ,fontweight="bold"
          ,backgroundcolor="yellow"
          ,style="italic")
# Out:
# Text(0.5, 1.0, 'graph')

# %%
sns.histplot(df["total_bill"],color="red")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.barplot(x="day",y="total_bill",data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.kdeplot(df["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#sns
#categorical plot --catplot
#relationship plot --replot
sns.relplot(x=df["total_bill"],y=df["tip"],data=df,color="red")

# %%
sns.catplot(x="day",y="total_bill",data=df,hue="smoker")

# %%
sns.catplot(x="day",y="total_bill",data=df,kind="box",hue="smoker")

# %%
sns.catplot(x="day",y="total_bill",data=df,kind="strip")

# %%
sns.catplot(x="day",y="total_bill",data=df,kind="swarm",color="orange")

# %%
sns.catplot(x="day",y="total_bill",data=df,kind="violin")

# %%
sns.catplot(x="day",y="total_bill",data=df,kind="point",hue="smoker")

# %%
sns.displot(df["total_bill"],kde="True",color="black")

# %%
sns.jointplot(x="total_bill",y="tip",data=df,color="skyblue")

# %%
sns.jointplot(x="total_bill",y="tip",data=df,kind="hex")

# %%
sns.pairplot(df)

# %%
sns.relplot(x=df["total_bill"],y="tip",data=df,color="black",kind="scatter")

# %%
sns.relplot(x="total_bill",y="tip",data=df,color="blue",hue="time",style="size",kind="scatter",col="time")

# %%
sns.relplot(x="total_bill",y="tip",data=df,color="blue",hue="time",style="size",kind="scatter",row="time")

# %%
sns.relplot(x="total_bill",y="tip",data=df,color="blue",hue="time",style="size",kind="scatter",col="size")

# %%
sns.relplot(x="total_bill",y="tip",data=df,color="blue",hue="time",style="size",kind="scatter",col="day")

# %%
sns.boxplot(df["total_bill"])  #oo outliers(Exceptions)
# Out:
# <Axes: ylabel='total_bill'>

# %%
##outliers --remove or transform
q1=df["total_bill"].quantile(0.25)
q3=df["total_bill"].quantile(0.75)
q1
# Out:
# 13.3475

# %%
q3
# Out:
# 24.127499999999998

# %%
iqr=q3-q1
iqr
# Out:
# 10.779999999999998

# %%
lower_bound=q1-1.5*iqr
upper_bound=q3+1.5*iqr

# %%
lower_bound
# Out:
# -2.8224999999999945

# %%
upper_bound
# Out:
# 40.29749999999999

# %%
df[df["total_bill"]>upper_bound]
df[df["total_bill"]<lower_bound]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %%
df=df[(df["total_bill"]>upper_bound) &
(df["total_bill"]<lower_bound)]
sns.boxplot(df["total_bill"])
# Out:
# <Axes: >
